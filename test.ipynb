# %%
import importlib.metadata
import spacy
from typing_extensions import Sentinel

print("typing_extensions:", importlib.metadata.version("typing_extensions"))
print("spacy:", spacy.__version__)
print("Sentinel OK")

nlp = spacy.load("en_core_web_sm")
print("spaCy model loaded OK")
# Out:
# typing_extensions: 4.15.0
# spacy: 3.8.11
# Sentinel OK
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[12], line 9
#       6 print("spacy:", spacy.__version__)
#       7 print("Sentinel OK")
# ----> 9 nlp = spacy.load("en_core_web_sm")
#      10 print("spaCy model loaded OK")
#
# File F:\anaconda\Lib\site-packages\spacy\__init__.py:52, in load(name, vocab, disable, enable, exclude, config)
#      28 def load(
#      29     name: Union[str, Path],
#      30     *,
#    (...)
#      35     config: Union[Dict[str, Any], Config] = util.SimpleFrozenDict(),
#      36 ) -> Language:
#      37     """Load a spaCy model from an installed package or a local path.
#      38
#      39     name (str): Package name or model path.
#    (...)
#      50     RETURNS (Language): The loaded nlp object.
#      51     """
# ---> 52     return util.load_model(
#      53         name,
#      54         vocab=vocab,
#      55         disable=disable,
#      56         enable=enable,
#      57         exclude=exclude,
#      58         config=config,
#      59     )
#
# File F:\anaconda\Lib\site-packages\spacy\util.py:531, in load_model(name, vocab, disable, enable, exclude, config)
#     529 if name in OLD_MODEL_SHORTCUTS:
#     530     raise IOError(Errors.E941.format(name=name, full=OLD_MODEL_SHORTCUTS[name]))  # type: ignore[index]
# --> 531 raise IOError(Errors.E050.format(name=name))
#
# OSError: [E050] Can't find model 'en_core_web_sm'. It doesn't seem to be a Python package or a valid path to a data directory.
